# %%
from dotenv import load_dotenv
import os

load_dotenv()

from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that can answer questions and help with tasks."),
    ("user", "{input}")
])

chain = prompt | llm

result = chain.invoke({"input": "What is the capital of France?"})
print(result)
# Out:
# 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
# content='The capital of France is Paris.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 32, 'total_tokens': 39, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_34a54ae93c', 'id': 'chatcmpl-BpuAHxGaydpecQ2rjffLxCoiVi1OY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--2c5bf639-d733-437d-a5cf-e27328e889f3-0' usage_metadata={'input_tokens': 32, 'output_tokens': 7, 'total_tokens': 39, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
